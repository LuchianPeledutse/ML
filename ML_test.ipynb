# %%
import numpy as np
from ML_models import DecisionTreeClassifier

# %%
y_vec = np.array([3,3,3,5]).reshape(-1,1)
print(y_vec.shape)
y_vec
# Out:
# (4, 1)
# array([[3],
#        [3],
#        [3],
#        [5]])

# %%
np.unique(y_vec)
# Out:
# array([3, 5])

# %%
np.unique(y_vec,return_counts = True)
# Out:
# (array([3, 5]), array([3, 1]))

# %%
dec_tree = DecisionTreeClassifier()

# %%
res_tup = dec_tree.calc_gini(y_vec)
res_tup
# Out:
# (4, array([3, 1]), np.float64(0.375))

# %%
res_tup[-1].item()
# Out:
# 0.375
